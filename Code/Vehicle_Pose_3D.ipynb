# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# !rm -rf YOLO3D
# Out:
# /content

# %%
# %cd /content/
# !git clone https://github.com/ruhyadi/YOLO3D
# Out:
# /content
# Cloning into 'YOLO3D'...
# remote: Enumerating objects: 738, done.
# remote: Counting objects: 100% (263/263), done.
# remote: Compressing objects: 100% (205/205), done.
# remote: Total 738 (delta 74), reused 231 (delta 46), pack-reused 475
# Receiving objects: 100% (738/738), 24.87 MiB | 17.16 MiB/s, done.
# Resolving deltas: 100% (266/266), done.

# %%
# install requirements
# %cd /content/YOLO3D

# !pip install -q --upgrade --no-cache-dir gdown
# Out:
# /content/YOLO3D

# %%
# get weights
# %cd /content/YOLO3D/weights/
# !python get_weights.py --weights 'resnet18'
# Out:
# /content/YOLO3D/weights
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1k_v1RrDO6da_NDhBtMZL5c0QSogCmiRn
# From (redirected): https://drive.google.com/uc?id=1k_v1RrDO6da_NDhBtMZL5c0QSogCmiRn&confirm=t&uuid=fe1b21dd-3288-4b28-ba61-e65f50efca4c
# To: /content/YOLO3D/weights/resnet18.pkl
# 100% 298M/298M [00:02<00:00, 101MB/s]

# %%
# !pip install torchvision==0.10.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.1/22.1 MB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.4/831.4 MB 2.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.9.1 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.9.1 which is incompatible.
# ...

# %%
import os
import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [atoi(c) for c in re.split(r'(\d+)', text)]

folder_path = '/content/drive/MyDrive/scene_11_changed'
image_files = os.listdir(folder_path)
image_files.sort(key=natural_keys)

for file in image_files:
    print(file)
# Out:
# frame0.jpg
# frame1.jpg
# frame2.jpg
# frame3.jpg
# frame4.jpg
# frame5.jpg
# frame6.jpg
# frame7.jpg
# frame8.jpg
# frame9.jpg
# frame10.jpg
# frame11.jpg
# frame12.jpg
# frame13.jpg
# frame14.jpg
# frame15.jpg
# frame16.jpg
# frame17.jpg
# frame18.jpg
# frame19.jpg
# frame20.jpg
# frame21.jpg
# frame22.jpg
# frame23.jpg
# frame24.jpg
# frame25.jpg
# frame26.jpg
# frame27.jpg
# frame28.jpg
# frame29.jpg
# frame30.jpg
# frame31.jpg
# frame32.jpg
# frame33.jpg
# frame34.jpg
# frame35.jpg
# frame36.jpg
# frame37.jpg
# frame38.jpg
# frame39.jpg
# frame40.jpg
# frame41.jpg
# frame42.jpg
# frame43.jpg
# frame44.jpg
# frame45.jpg
# frame46.jpg
# frame47.jpg
# frame48.jpg
# frame49.jpg
# frame50.jpg
# frame51.jpg
# frame52.jpg
# frame53.jpg
# frame54.jpg
# frame55.jpg
# frame56.jpg
# frame57.jpg
# frame58.jpg
# frame59.jpg
# frame60.jpg
# frame61.jpg
# frame62.jpg
# frame63.jpg
# frame64.jpg
# frame65.jpg
# frame66.jpg
# frame67.jpg
# frame68.jpg
# frame69.jpg
# frame70.jpg
# frame71.jpg
# ...

# %%
# %cd /content/YOLO3D/
# !python inference.py \
  --weights yolov5s.pt \
  --source /content/drive/MyDrive/scene_11_fixed \
  --reg_weights weights/resnet18.pkl \
  --model_select resnet18 \
  --output_path runs01 \
  --save_result
# Out:
# Streaming output truncated to the last 5000 lines.
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/scene_11_fixed/frame209.jpg: 224x640 2 cars, Done. (0.008s)
# Speed: 0.3ms pre-process, 7.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# location [-5.551644191317566, -0.23718544353638293, 27.861426585403528]
# X [[1.8082828521728516, -0.7463984489440918, -0.8196044564247131], [-1.8082828521728516, -0.7463984489440918, 0.8196044564247131], [-1.8082828521728516, 0.7463984489440918, 0.8196044564247131], [-1.8082828521728516, 0.7463984489440918, -0.8196044564247131]]
# 465
# 166
# 0.0
# -0.0
# 1.476467712027154
# [{'type': 'sedan', 'red': 'no', 'yaw': 1.476467712027154, 'u': 191.69082125603865, 'v': 113.32266666666666}]
# location [-0.5177043586815078, 0.06507063504411192, 10.392638167267982]
# ...

# %%
# !zip -r scene_11_6d_outputs.zip /content/YOLO3D/scene_11_output
# Out:
#   adding: content/YOLO3D/scene_11_output/ (stored 0%)
#   adding: content/YOLO3D/scene_11_output/frame_065_data.json (deflated 52%)
#   adding: content/YOLO3D/scene_11_output/frame_173_data.json (deflated 58%)
#   adding: content/YOLO3D/scene_11_output/frame_054_data.json (deflated 56%)
#   adding: content/YOLO3D/scene_11_output/frame_011_data.json (deflated 51%)
#   adding: content/YOLO3D/scene_11_output/frame_141_data.json (deflated 63%)
#   adding: content/YOLO3D/scene_11_output/frame_304_data.json (deflated 44%)
#   adding: content/YOLO3D/scene_11_output/frame_184_data.json (deflated 51%)
#   adding: content/YOLO3D/scene_11_output/frame_182_data.json (deflated 52%)
#   adding: content/YOLO3D/scene_11_output/frame_250_data.json (deflated 54%)
#   adding: content/YOLO3D/scene_11_output/frame_218_data.json (deflated 41%)
#   adding: content/YOLO3D/scene_11_output/frame_403_data.json (deflated 38%)
#   adding: content/YOLO3D/scene_11_output/frame_042_data.json (deflated 56%)
# ...
